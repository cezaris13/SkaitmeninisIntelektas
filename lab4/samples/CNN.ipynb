# %%
# Parameters for CNN
classNames: list = ['お','き','す', 'つ', 'な', 'は', 'ま', 'や', 'れ', 'を'] # duomenų klasės
numClasses: int = len(classNames) # Duomenų klasių skaičius
imageSize: int = 28 # Paveikslėlio dydis
dataSet: int  = 70000 # Duomenų rinkinio dydis
activationFunction: str = "relu" # Aktyvacijos funkcija
lossFunction = "categorical_crossentropy" # Loss function
modelFileName: str = "model.h5" # Modelio failo pavadinimas

#training data
testSize: float = 0.1 # Testavimo duomenų dydis
validationSize: float = 0.1 # Validavimo duomenų dydis
batchSize: int = 100 #
epochs: int = 9 # Epochų skaičius
learningRate: float = 0.005 # Mokymo greitis
momentum: float = 0.9 #
dropout: float = 0.2 # Išmetimo sluoksnio tikimybė

# %%
# !pip install python-mnist
# Out:
# Collecting python-mnist
#   Downloading python_mnist-0.7-py2.py3-none-any.whl (9.6 kB)
# Installing collected packages: python-mnist
# Successfully installed python-mnist-0.7

# %% [markdown]
# # New section

# %%
from sklearn.model_selection import train_test_split
import numpy as np
from matplotlib.figure import Figure
from keras import optimizers
from keras.models import Sequential, load_model
from keras.layers import Conv2D, Dense, Flatten, MaxPooling2D, Dropout, BatchNormalization
from keras.callbacks import LearningRateScheduler, TensorBoard
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns
from mnist import MNIST

# plt.rcParams['font.family'] = 'Hiragino Maru Gothic Pro'

# %%
# # Nuskaitoma informacija is failo
def getData() -> (list, list):
    mndata = MNIST('samples')
    imagesTrain, labelsTrain = mndata.load_training()
    imagesTest, labelsTest = mndata.load_testing()
    return imagesTrain+imagesTest, labelsTrain+labelsTest

# išskaidyti duomenų aibę į mokymo ir testavimo aibes
def splitData(data:list, labels:list, validationSize: float, testSize: float) -> (list, list, list, list, list, list):
    trainData, testData, trainLabels, testLabels = train_test_split(data, labels, test_size=testSize, random_state=42)
    trainData, validationData, trainLabels, validationLabels = train_test_split(trainData, trainLabels, test_size=validationSize, random_state=42)
    return trainData, validationData, testData, trainLabels, validationLabels, testLabels

# Suformuoti masyvus [0,0...1,...0,0], kur vienetas reiškia esamą duomenų klasės reikšmę.
def reshapeLabels(labels: list, numClasses: int) -> list:
    return [ [1 if i == label else 0 for i in range(numClasses)] for label in labels]

# Duomenų aibės elementus padaliname is 255, kad patektų į intevalą [0,1].
def normalizeData(data: list) -> list:
    data = np.array(data)
    return [ i / 255.0 for i in data]

# Duomenų aibę, nuskaitytą iš failo paverčiame į [10000,32,32,3] masyvą, kur 10000 - paveikslėlių kiekis duomenų faile, 32 - paveikslėlio aukštis ir plotis, 3 - RGB spalvu reikšmės.
def reshapeData(data: list, imageSize: int) -> list:
    modifiedData: [[[float]]] = []
    for i in data:
        imageMatrix: [[float]] = []
        for j in range(imageSize):
            combList : [float] = []
            for k in range(imageSize):
                combList.append(i[j*imageSize+k])
            imageMatrix.append(combList)
        modifiedData.append(imageMatrix)
    return modifiedData

# nuskaitomi visi failai, kuriuose yra duomenys, juos performatuojam ir išsaugome į kitus failus.
def prepareData(imageSize: int, numClasses: int) -> (list, list):
    newData: list = []
    newLabels: list = []
    data, labels = getData()
    data = normalizeData(data)
    data = reshapeData(data, imageSize)
    labels = reshapeLabels(labels, numClasses)
    newData.extend(data)
    newLabels.extend(labels)
    newData = np.array(newData)
    newLabels = np.array(newLabels)
    return newData, newLabels

def lenet(dropout:float) -> Sequential: # iki galo issiaiskinti kaip veikia
    model = Sequential()
    model.add(Conv2D(6, (5, 5), padding='valid', activation = activationFunction, kernel_initializer='he_normal', input_shape=(28,28,1)))
    model.add(MaxPooling2D((2, 2), strides=(2, 2)))
    model.add(Dropout(dropout)) # 1
    model.add(Conv2D(16, (5, 5), padding='valid', activation = activationFunction, kernel_initializer='he_normal'))
    model.add(MaxPooling2D((2, 2), strides=(2, 2)))
    model.add(Flatten())
    model.add(Dense(120, activation = activationFunction, kernel_initializer='he_normal'))
    model.add(Dropout(dropout)) # 2
    model.add(Dense(84, activation = activationFunction, kernel_initializer='he_normal'))
    model.add(Dense(numClasses, activation = 'softmax', kernel_initializer='he_normal'))
    sgd = optimizers.legacy.SGD(learning_rate=learningRate, momentum=momentum, nesterov=True)
    model.compile(loss=lossFunction, optimizer=sgd, metrics=['accuracy'])
    print(model.summary())
    return model

def lenet1() -> Sequential: # iki galo issiaiskinti kaip veikia
    model = Sequential()
    model.add(Conv2D(6, (5, 5), padding='valid', activation = activationFunction, kernel_initializer='he_normal', input_shape=(28,28,1)))
    model.add(MaxPooling2D((2, 2), strides=(2, 2)))
    model.add(Dropout(dropout)) # 1
    model.add(Conv2D(16, (5, 5), padding='valid', activation = activationFunction, kernel_initializer='he_normal'))
    model.add(MaxPooling2D((2, 2), strides=(2, 2)))
    model.add(Flatten())
    model.add(Dense(120, activation = activationFunction, kernel_initializer='he_normal'))
    # model.add(Dropout(dropout)) # 2
    model.add(Dense(84, activation = activationFunction, kernel_initializer='he_normal'))
    model.add(Dense(numClasses, activation = 'softmax', kernel_initializer='he_normal'))
    sgd = optimizers.legacy.SGD(learning_rate=learningRate, momentum=momentum, nesterov=True)
    model.compile(loss=lossFunction, optimizer=sgd, metrics=['accuracy'])
    print(model.summary())
    return model

def lenet2() -> Sequential: # iki galo issiaiskinti kaip veikia
    model = Sequential()
    model.add(Conv2D(6, (5, 5), padding='valid', activation = activationFunction, kernel_initializer='he_normal', input_shape=(28,28,1)))
    model.add(MaxPooling2D((2, 2), strides=(2, 2)))
    model.add(Dropout(dropout)) # 1
    model.add(Conv2D(16, (5, 5), padding='valid', activation = activationFunction, kernel_initializer='he_normal'))
    model.add(MaxPooling2D((2, 2), strides=(2, 2)))
    model.add(Flatten())
    model.add(Dense(120, activation = activationFunction, kernel_initializer='he_normal'))
    model.add(Dropout(dropout)) # 2
    model.add(Dense(84, activation = activationFunction, kernel_initializer='he_normal'))
    model.add(Dense(numClasses, activation = 'softmax', kernel_initializer='he_normal'))
    sgd = optimizers.legacy.SGD(learning_rate=learningRate, momentum=momentum, nesterov=True)
    model.compile(loss=lossFunction, optimizer=sgd, metrics=['accuracy'])
    print(model.summary())
    return model

def lenetNorm(normalization:bool) -> Sequential: # iki galo issiaiskinti kaip veikia
    model = Sequential()
    model.add(Conv2D(6, (5, 5), padding='valid', activation = activationFunction, kernel_initializer='he_normal', input_shape=(28,28,1)))
    if normalization == True:
        model.add(BatchNormalization())

    model.add(MaxPooling2D((2, 2), strides=(2, 2)))
    model.add(Dropout(dropout)) # 1
    model.add(Conv2D(16, (5, 5), padding='valid', activation = activationFunction, kernel_initializer='he_normal'))
    if normalization == True:
        model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2), strides=(2, 2)))
    model.add(Flatten())
    model.add(Dense(120, activation = activationFunction, kernel_initializer='he_normal'))
    model.add(Dropout(dropout)) # 2
    model.add(Dense(84, activation = activationFunction, kernel_initializer='he_normal'))
    model.add(Dense(numClasses, activation = 'softmax', kernel_initializer='he_normal'))
    sgd = optimizers.legacy.SGD(learning_rate=learningRate, momentum=momentum, nesterov=True)
    model.compile(loss=lossFunction, optimizer=sgd, metrics=['accuracy'])
    print(model.summary())
    return model

def lenetActivation(activationFunction:str) -> Sequential: # iki galo issiaiskinti kaip veikia
    model = Sequential()
    model.add(Conv2D(6, (5, 5), padding='valid', activation = activationFunction, kernel_initializer='he_normal', input_shape=(28,28,1)))
    model.add(MaxPooling2D((2, 2), strides=(2, 2)))
    model.add(Dropout(dropout)) # 1
    model.add(Conv2D(16, (5, 5), padding='valid', activation = activationFunction, kernel_initializer='he_normal'))
    model.add(MaxPooling2D((2, 2), strides=(2, 2)))
    model.add(Flatten())
    model.add(Dense(120, activation = activationFunction, kernel_initializer='he_normal'))
    model.add(Dropout(dropout)) # 2
    model.add(Dense(84, activation = activationFunction, kernel_initializer='he_normal'))
    model.add(Dense(numClasses, activation = 'softmax', kernel_initializer='he_normal'))
    sgd = optimizers.legacy.SGD(learning_rate=learningRate, momentum=momentum, nesterov=True)
    model.compile(loss=lossFunction, optimizer=sgd, metrics=['accuracy'])
    print(model.summary())
    return model

def lenetOptimization(optimizer) -> Sequential: # iki galo issiaiskinti kaip veikia
    model = Sequential()
    model.add(Conv2D(6, (5, 5), padding='valid', activation = activationFunction, kernel_initializer='he_normal', input_shape=(28,28,1)))
    model.add(MaxPooling2D((2, 2), strides=(2, 2)))
    model.add(Dropout(dropout)) # 1
    model.add(Conv2D(16, (5, 5), padding='valid', activation = activationFunction, kernel_initializer='he_normal'))
    model.add(MaxPooling2D((2, 2), strides=(2, 2)))
    model.add(Flatten())
    model.add(Dense(120, activation = activationFunction, kernel_initializer='he_normal'))
    model.add(Dropout(dropout)) # 2
    model.add(Dense(84, activation = activationFunction, kernel_initializer='he_normal'))
    model.add(Dense(numClasses, activation = 'softmax', kernel_initializer='he_normal'))
    sgd = optimizers.legacy.SGD(learning_rate=learningRate, momentum=momentum, nesterov=True)
    model.compile(loss=lossFunction, optimizer=optimizer, metrics=['accuracy'])
    print(model.summary())
    return model

# https://thecleverprogrammer.com/2021/12/13/alexnet-architecture-using-python/
def alexNet() -> Sequential:
    model = Sequential()
    model.add(Conv2D(96,(11, 11), activation=activationFunction, input_shape=(28, 28, 1)))
    model.add(BatchNormalization())
    model.add(MaxPooling2D((3, 3), strides= (2, 2)))
    model.add(Conv2D(256, (5, 5), strides=(1, 1), activation=activationFunction, padding="same"))
    model.add(BatchNormalization())
    model.add(MaxPooling2D((3, 3), strides=(2, 2)))
    model.add(Conv2D(384, (3, 3), strides=(1, 1), activation=activationFunction, padding="same"))
    model.add(BatchNormalization())
    model.add(Conv2D(384, (3, 3), strides=(1, 1), activation=activationFunction, padding="same"))
    model.add(BatchNormalization())
    model.add(Conv2D(256, (3, 3), strides=(1, 1), activation=activationFunction, padding="same"))
    model.add(BatchNormalization())
    model.add(MaxPooling2D((3, 3), strides=(2, 2)))
    model.add(Flatten())
    model.add(Dense(4096, activation=activationFunction))
    model.add(Dropout(dropout))
    model.add(Dense(10, activation="softmax"))
    sgd = optimizers.legacy.SGD(learning_rate=learningRate, momentum=momentum, nesterov=True)
    model.compile(loss=lossFunction, optimizer=sgd, metrics=['accuracy'])
    print(model.summary())
    return model

def simple() -> Sequential:
    model = Sequential()
    model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', input_shape=(28, 28, 1)))
    model.add(MaxPooling2D((2, 2)))
    model.add(Conv2D(64, (3, 3), activation=activationFunction, kernel_initializer='he_normal'))
    model.add(MaxPooling2D((2, 2)))
    model.add(Conv2D(64, (3, 3), activation=activationFunction, kernel_initializer='he_normal'))
    model.add(Flatten())
    model.add(Dense(64, activation=activationFunction, kernel_initializer='he_normal'))
    model.add(Dense(10, activation='softmax', kernel_initializer='he_normal'))
    sgd = optimizers.legacy.SGD(learning_rate=learningRate, momentum=momentum, nesterov=True)
    model.compile(loss=lossFunction, optimizer=sgd, metrics=['accuracy'])
    print(model.summary())
    return model

def scheduler(epoch: int) -> float:
    if epoch < 100:
        return 0.01
    if epoch < 150:
        return 0.005
    return 0.001

# Modelio mokymas naudojantis mokymo ir testavimo duomenimis, bei pateikiant mokymo algorithmą.
def trainModel(trainData: np.array,validationData: np.array, trainLabels: np.array, validationLabels: np.array, learningModel: callable) -> list:
    model: Sequential = learningModel()
    print(model.summary())

    # set callback
    tensorBoard = TensorBoard(log_dir='./lenet', histogram_freq=0)
    change_lr = LearningRateScheduler(scheduler)
    cbks = [change_lr,tensorBoard]

    modelHistory = model.fit(trainData, trainLabels,
                batch_size=batchSize,
                epochs=epochs,
                callbacks=cbks,
                validation_data=(validationData, validationLabels),
                shuffle=True)

    model.save(modelFileName)
    return modelHistory
# Esamas duomenų klasės maskes paverčiame į klasės indeksą.
def labelToClass(label: list) -> int:
    for i in range(len(label)):
        if label[i] == 1:
            return i

# Turėdami tikimybes klasėms, kurias priskyrė modelis, paverčiame pasiimame klasės indeksą su didžiausią tikimybe.
def probabilityToClass(label:list) -> int:
    return np.argmax(label)

# Palyginame modelio spėjimus su tikromis klasėmis ir paskaičiuojame tikslumą.
def accuracy(predictions: list, labels: list) -> float:
    correct: int = 0
    for i in range(len(predictions)):
        if predictions[i] == labelToClass(labels[i]):
            correct += 1
    return correct / len(predictions)

# Palyginame modelio spėjimus su tikromis klasėmis ir paskaičiuojame vidutinį kvadratinį nuokrypį.
def loss(model: Sequential,data:np.array, labels: np.array) -> float:
    MSE:int = 0
    classesPredicted = [probabilityToClass(i) for i in model.predict(data)]
    for i in range(len(data)):
        MSE += np.square(labelToClass(labels[i]) - classesPredicted[i])
    return MSE / len(data)

# Nupiešiame modelio confusion matrix.
def confusionMatrix(model: Sequential, data: np.array, labels: np.array):
    predictions = model.predict(data)
    predictions = [probabilityToClass(i) for i in predictions]
    cm = confusion_matrix([labelToClass(i) for i in labels],predictions)
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    plt.figure(figsize = (10,10))
    sns.heatmap(cm, annot=True, xticklabels=classNames, yticklabels = classNames, square=True, cmap='Greens')
    plt.xlabel("Predicted label")
    plt.ylabel("True label")

# Nupiešiame paveikslėlius ir jų spėjimus su tikimybėmis.
def drawImagesAndPredictions(model: Sequential, data: np.array, labels: np.array, rows:int=8, columns: int=8):
    figure: Figure = plt.figure(figsize=(10, 7))

    nData: np.array = data[:rows*columns]
    labels: np.array = labels[:rows*columns]

    model = load_model(modelFileName)
    modelPredictions = model.predict(nData)
    modelPredictedClasses = [probabilityToClass(i) for i in modelPredictions]

    for i in range(len(nData)):
        figure.add_subplot(rows, columns, i+1)
        plt.imshow(nData[i],cmap='gray')
        plt.axis('off')
        title = classNames[modelPredictedClasses[i]] + "\n (" + round(max(modelPredictions[i]),3).__str__() + ")"
        if modelPredictedClasses[i] != labelToClass(labels[i]):
            plt.title(title,color="red")
        else:
            plt.title(title,color="green")
        plt.tight_layout(pad=0.5)

# %%
data, labels = prepareData(imageSize, numClasses)

# %%
trainData, validationData, testData, trainLabels, validationLabels, testLabels = splitData(data, labels, validationSize, testSize)
# history = trainModel(trainData,testData,trainLabels,testLabels, lenet)

# print("Train data accuracy: ", history.history['accuracy'][-1])
# print("Train data loss: ", history.history['loss'][-1])
# print("Test data accuracy: ", history.history['val_accuracy'][-1])
# print("Test data loss: ", history.history['val_loss'][-1])

# %%
# model = load_model(modelFileName)

# %%
# confusionMatrix(model, testData, testLabels)

# %%
# drawImagesAndPredictions(model, testData, testLabels)

# %%
lenetHistory = trainModel(trainData,validationData,trainLabels,validationLabels, lenet)
simpleHistory = trainModel(trainData,validationData,trainLabels,validationLabels, simple)
# alexNetHistory = trainModel(trainData,testData,trainLabels,testLabels, alexNet)

# %%
alexNetHistory = trainModel(trainData,validationData,trainLabels,validationLabels, alexNet)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_5 (Conv2D)           (None, 18, 18, 96)        11712
#
#  batch_normalization_5 (Bat  (None, 18, 18, 96)        384
#  chNormalization)
#
#  max_pooling2d_3 (MaxPoolin  (None, 8, 8, 96)          0
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 8, 8, 256)         614656
#
#  batch_normalization_6 (Bat  (None, 8, 8, 256)         1024
#  chNormalization)
#
#  max_pooling2d_4 (MaxPoolin  (None, 3, 3, 256)         0
#  g2D)
#
#  conv2d_7 (Conv2D)           (None, 3, 3, 384)         885120
#
#  batch_normalization_7 (Bat  (None, 3, 3, 384)         1536
#  chNormalization)
#
#  conv2d_8 (Conv2D)           (None, 3, 3, 384)         1327488
#
#  batch_normalization_8 (Bat  (None, 3, 3, 384)         1536
#  chNormalization)
#
#  conv2d_9 (Conv2D)           (None, 3, 3, 256)         884992
#
#  batch_normalization_9 (Bat  (None, 3, 3, 256)         1024
#  chNormalization)
#
#  max_pooling2d_5 (MaxPoolin  (None, 1, 1, 256)         0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 4096)              1052672
#
#  dropout_1 (Dropout)         (None, 4096)              0
#
#  dense_3 (Dense)             (None, 10)                40970
#
# =================================================================
# Total params: 4823114 (18.40 MB)
# Trainable params: 4820362 (18.39 MB)
# Non-trainable params: 2752 (10.75 KB)
# _________________________________________________________________
# None
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_5 (Conv2D)           (None, 18, 18, 96)        11712
#
#  batch_normalization_5 (Bat  (None, 18, 18, 96)        384
#  chNormalization)
#
#  max_pooling2d_3 (MaxPoolin  (None, 8, 8, 96)          0
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 8, 8, 256)         614656
#
#  batch_normalization_6 (Bat  (None, 8, 8, 256)         1024
#  chNormalization)
#
#  max_pooling2d_4 (MaxPoolin  (None, 3, 3, 256)         0
#  g2D)
#
#  conv2d_7 (Conv2D)           (None, 3, 3, 384)         885120
#
#  batch_normalization_7 (Bat  (None, 3, 3, 384)         1536
#  chNormalization)
#
#  conv2d_8 (Conv2D)           (None, 3, 3, 384)         1327488
#
#  batch_normalization_8 (Bat  (None, 3, 3, 384)         1536
#  chNormalization)
#
#  conv2d_9 (Conv2D)           (None, 3, 3, 256)         884992
#
#  batch_normalization_9 (Bat  (None, 3, 3, 256)         1024
#  chNormalization)
#
#  max_pooling2d_5 (MaxPoolin  (None, 1, 1, 256)         0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 4096)              1052672
#
#  dropout_1 (Dropout)         (None, 4096)              0
#
#  dense_3 (Dense)             (None, 10)                40970
#
# =================================================================
# Total params: 4823114 (18.40 MB)
# Trainable params: 4820362 (18.39 MB)
# Non-trainable params: 2752 (10.75 KB)
# _________________________________________________________________
# None
# Epoch 1/9
# 567/567 [==============================] - 11s 18ms/step - loss: 0.2633 - accuracy: 0.9194 - val_loss: 0.2128 - val_accuracy: 0.9370 - lr: 0.0100
# Epoch 2/9
# 567/567 [==============================] - 9s 15ms/step - loss: 0.0704 - accuracy: 0.9787 - val_loss: 0.1068 - val_accuracy: 0.9665 - lr: 0.0100
# Epoch 3/9
# 567/567 [==============================] - 9s 16ms/step - loss: 0.0363 - accuracy: 0.9887 - val_loss: 0.0657 - val_accuracy: 0.9790 - lr: 0.0100
# Epoch 4/9
# 567/567 [==============================] - 9s 15ms/step - loss: 0.0185 - accuracy: 0.9946 - val_loss: 0.0566 - val_accuracy: 0.9824 - lr: 0.0100
# Epoch 5/9
# 567/567 [==============================] - 9s 15ms/step - loss: 0.0081 - accuracy: 0.9980 - val_loss: 0.0503 - val_accuracy: 0.9830 - lr: 0.0100
# Epoch 6/9
# 567/567 [==============================] - 9s 15ms/step - loss: 0.0041 - accuracy: 0.9993 - val_loss: 0.0453 - val_accuracy: 0.9848 - lr: 0.0100
# Epoch 7/9
# 567/567 [==============================] - 10s 17ms/step - loss: 0.0017 - accuracy: 0.9999 - val_loss: 0.0434 - val_accuracy: 0.9873 - lr: 0.0100
# Epoch 8/9
# 567/567 [==============================] - 9s 15ms/step - loss: 0.0011 - accuracy: 0.9999 - val_loss: 0.0419 - val_accuracy: 0.9875 - lr: 0.0100
# Epoch 9/9
# 567/567 [==============================] - 9s 15ms/step - loss: 6.6815e-04 - accuracy: 1.0000 - val_loss: 0.0421 - val_accuracy: 0.9867 - lr: 0.0100
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
print("Test data accuracy: ", alexNetHistory.history['val_accuracy'][-1])
print("Test data loss: ", alexNetHistory.history['val_loss'][-1])
# Out:
# Test data accuracy:  0.9866666793823242
# Test data loss:  0.04209599271416664

# %%
# predictionValues = model.predict(testData)
# predictionValues = [probabilityToClass(i) for i in predictionValues]
# print("accuracy: ", accuracy(predictionValues, testLabels))
# print("loss: ", loss(model, testData, testLabels))

# %%
plt.plot(range(1,epochs+1),lenetHistory.history['val_loss'])
plt.plot(range(1,epochs+1),simpleHistory.history['val_loss'])
plt.plot(range(1,epochs+1),alexNetHistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['LeNet', 'Simple','AlexNet'], loc='lower right')
plt.show()

# %%
plt.plot(range(1,epochs+1),lenetHistory.history['val_accuracy'])
plt.plot(range(1,epochs+1),simpleHistory.history['val_accuracy'])
plt.plot(range(1,epochs+1),alexNetHistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.legend(['LeNet', 'Simple','AlexNet'], loc='lower right')
plt.xlabel('Epoch')

# %%
# lenetHistory = trainModel(trainData,validationData,trainLabels,validationLabels, lenet)
# lenet1History = trainModel(trainData,validationData,trainLabels,validationLabels, lenet1)
# lenet2History = trainModel(trainData,validationData,trainLabels,validationLabels, lenet2)

lenetHistory = trainModel(trainData,validationData,trainLabels,validationLabels, lenet,0.2)
lenet1History = trainModel(trainData,validationData,trainLabels,validationLabels, lenet,0.4)
lenet2History = trainModel(trainData,validationData,trainLabels,validationLabels, lenet,0.6)

# %%
plt.plot(range(1,epochs+1),lenetHistory.history['val_loss'])
plt.plot(range(1,epochs+1),lenet1History.history['val_loss'])
plt.plot(range(1,epochs+1),lenet2History.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
# plt.legend(['LeNet 0 dropout', 'Lenet 1 dropout','Lenet 2 dropout'], loc='lower right')
plt.legend(['LeNet 0.2 dropout', 'Lenet 0.4 dropout','Lenet 0.6 dropout'], loc='lower right')
plt.show()

# %%
plt.plot(range(1,epochs+1),lenetHistory.history['val_accuracy'])
plt.plot(range(1,epochs+1),lenet1History.history['val_accuracy'])
plt.plot(range(1,epochs+1),lenet2History.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
# plt.legend(['LeNet 0 dropout', 'Lenet 1 dropout','Lenet 2 dropout'], loc='lower right')
plt.legend(['LeNet 0.2 dropout', 'Lenet 0.4 dropout','Lenet 0.6 dropout'], loc='lower right')
plt.show()

# %%
lenetHistory = trainModel(trainData,validationData,trainLabels,validationLabels, lenetNorm,False)
lenetNormHistory = trainModel(trainData,validationData,trainLabels,validationLabels, lenetNorm,True)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 24, 24, 6)         156
#
#  max_pooling2d (MaxPooling2  (None, 12, 12, 6)         0
#  D)
#
#  dropout (Dropout)           (None, 12, 12, 6)         0
#
#  conv2d_1 (Conv2D)           (None, 8, 8, 16)          2416
#
#  max_pooling2d_1 (MaxPoolin  (None, 4, 4, 16)          0
#  g2D)
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 120)               30840
#
#  dropout_1 (Dropout)         (None, 120)               0
#
#  dense_1 (Dense)             (None, 84)                10164
#
#  dense_2 (Dense)             (None, 10)                850
#
# =================================================================
# Total params: 44426 (173.54 KB)
# Trainable params: 44426 (173.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 24, 24, 6)         156
#
#  max_pooling2d (MaxPooling2  (None, 12, 12, 6)         0
#  D)
#
#  dropout (Dropout)           (None, 12, 12, 6)         0
#
#  conv2d_1 (Conv2D)           (None, 8, 8, 16)          2416
#
#  max_pooling2d_1 (MaxPoolin  (None, 4, 4, 16)          0
#  g2D)
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 120)               30840
#
#  dropout_1 (Dropout)         (None, 120)               0
#
#  dense_1 (Dense)             (None, 84)                10164
#
#  dense_2 (Dense)             (None, 10)                850
#
# =================================================================
# Total params: 44426 (173.54 KB)
# Trainable params: 44426 (173.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/15
# 567/567 [==============================] - 12s 4ms/step - loss: 1.5111 - accuracy: 0.4907 - val_loss: 0.8107 - val_accuracy: 0.7600 - lr: 0.0100
# Epoch 2/15
# 567/567 [==============================] - 2s 4ms/step - loss: 0.9218 - accuracy: 0.6997 - val_loss: 0.5619 - val_accuracy: 0.8359 - lr: 0.0100
# Epoch 3/15
# 567/567 [==============================] - 3s 5ms/step - loss: 0.7386 - accuracy: 0.7626 - val_loss: 0.4440 - val_accuracy: 0.8700 - lr: 0.0100
# Epoch 4/15
# 567/567 [==============================] - 3s 5ms/step - loss: 0.6377 - accuracy: 0.7950 - val_loss: 0.3757 - val_accuracy: 0.8884 - lr: 0.0100
# Epoch 5/15
# 567/567 [==============================] - 2s 4ms/step - loss: 0.5660 - accuracy: 0.8186 - val_loss: 0.3140 - val_accuracy: 0.9030 - lr: 0.0100
# Epoch 6/15
# 567/567 [==============================] - 2s 4ms/step - loss: 0.5188 - accuracy: 0.8331 - val_loss: 0.2904 - val_accuracy: 0.9110 - lr: 0.0100
# Epoch 7/15
# 567/567 [==============================] - 2s 4ms/step - loss: 0.4814 - accuracy: 0.8498 - val_loss: 0.2607 - val_accuracy: 0.9197 - lr: 0.0100
# Epoch 8/15
# 567/567 [==============================] - 3s 4ms/step - loss: 0.4528 - accuracy: 0.8560 - val_loss: 0.2401 - val_accuracy: 0.9284 - lr: 0.0100
# Epoch 9/15
# 567/567 [==============================] - 3s 5ms/step - loss: 0.4243 - accuracy: 0.8672 - val_loss: 0.2289 - val_accuracy: 0.9294 - lr: 0.0100
# Epoch 10/15
# 567/567 [==============================] - 2s 4ms/step - loss: 0.4074 - accuracy: 0.8728 - val_loss: 0.2062 - val_accuracy: 0.9383 - lr: 0.0100
# Epoch 11/15
# 567/567 [==============================] - 2s 4ms/step - loss: 0.3864 - accuracy: 0.8771 - val_loss: 0.1990 - val_accuracy: 0.9386 - lr: 0.0100
# Epoch 12/15
# 567/567 [==============================] - 2s 4ms/step - loss: 0.3740 - accuracy: 0.8844 - val_loss: 0.1851 - val_accuracy: 0.9449 - lr: 0.0100
# Epoch 13/15
# 567/567 [==============================] - 2s 4ms/step - loss: 0.3566 - accuracy: 0.8892 - val_loss: 0.1774 - val_accuracy: 0.9440 - lr: 0.0100
# Epoch 14/15
# 567/567 [==============================] - 3s 5ms/step - loss: 0.3361 - accuracy: 0.8951 - val_loss: 0.1718 - val_accuracy: 0.9470 - lr: 0.0100
# Epoch 15/15
# 567/567 [==============================] - 2s 4ms/step - loss: 0.3276 - accuracy: 0.8980 - val_loss: 0.1631 - val_accuracy: 0.9510 - lr: 0.0100
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 24, 24, 6)         156
#
#  batch_normalization (Batch  (None, 24, 24, 6)         24
#  Normalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 12, 12, 6)         0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 12, 12, 6)         0
#
#  conv2d_3 (Conv2D)           (None, 8, 8, 16)          2416
#
#  batch_normalization_1 (Bat  (None, 8, 8, 16)          64
#  chNormalization)
#
#  max_pooling2d_3 (MaxPoolin  (None, 4, 4, 16)          0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 120)               30840
#
#  dropout_3 (Dropout)         (None, 120)               0
#
#  dense_4 (Dense)             (None, 84)                10164
#
#  dense_5 (Dense)             (None, 10)                850
#
# =================================================================
# Total params: 44514 (173.88 KB)
# Trainable params: 44470 (173.71 KB)
# Non-trainable params: 44 (176.00 Byte)
# _________________________________________________________________
# None
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 24, 24, 6)         156
#
#  batch_normalization (Batch  (None, 24, 24, 6)         24
#  Normalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 12, 12, 6)         0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 12, 12, 6)         0
#
#  conv2d_3 (Conv2D)           (None, 8, 8, 16)          2416
#
#  batch_normalization_1 (Bat  (None, 8, 8, 16)          64
#  chNormalization)
#
#  max_pooling2d_3 (MaxPoolin  (None, 4, 4, 16)          0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 120)               30840
#
#  dropout_3 (Dropout)         (None, 120)               0
#
#  dense_4 (Dense)             (None, 84)                10164
#
#  dense_5 (Dense)             (None, 10)                850
#
# =================================================================
# Total params: 44514 (173.88 KB)
# Trainable params: 44470 (173.71 KB)
# Non-trainable params: 44 (176.00 Byte)
# _________________________________________________________________
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# None
# Epoch 1/15
# 567/567 [==============================] - 3s 5ms/step - loss: 1.3027 - accuracy: 0.5700 - val_loss: 0.6654 - val_accuracy: 0.7951 - lr: 0.0100
# Epoch 2/15
# 567/567 [==============================] - 2s 4ms/step - loss: 0.8038 - accuracy: 0.7395 - val_loss: 0.4794 - val_accuracy: 0.8525 - lr: 0.0100
# Epoch 3/15
# 567/567 [==============================] - 3s 5ms/step - loss: 0.6544 - accuracy: 0.7905 - val_loss: 0.3911 - val_accuracy: 0.8776 - lr: 0.0100
# Epoch 4/15
# 567/567 [==============================] - 2s 4ms/step - loss: 0.5698 - accuracy: 0.8217 - val_loss: 0.3327 - val_accuracy: 0.8930 - lr: 0.0100
# Epoch 5/15
# 567/567 [==============================] - 2s 4ms/step - loss: 0.5067 - accuracy: 0.8414 - val_loss: 0.2953 - val_accuracy: 0.9060 - lr: 0.0100
# Epoch 6/15
# 567/567 [==============================] - 2s 4ms/step - loss: 0.4640 - accuracy: 0.8547 - val_loss: 0.2698 - val_accuracy: 0.9138 - lr: 0.0100
# Epoch 7/15
# 567/567 [==============================] - 2s 4ms/step - loss: 0.4291 - accuracy: 0.8657 - val_loss: 0.2459 - val_accuracy: 0.9230 - lr: 0.0100
# Epoch 8/15
# 567/567 [==============================] - 3s 5ms/step - loss: 0.4010 - accuracy: 0.8745 - val_loss: 0.2280 - val_accuracy: 0.9275 - lr: 0.0100
# Epoch 9/15
# 567/567 [==============================] - 2s 4ms/step - loss: 0.3790 - accuracy: 0.8816 - val_loss: 0.2095 - val_accuracy: 0.9362 - lr: 0.0100
# Epoch 10/15
# 567/567 [==============================] - 2s 4ms/step - loss: 0.3594 - accuracy: 0.8874 - val_loss: 0.1982 - val_accuracy: 0.9386 - lr: 0.0100
# Epoch 11/15
# 567/567 [==============================] - 3s 5ms/step - loss: 0.3438 - accuracy: 0.8922 - val_loss: 0.1894 - val_accuracy: 0.9411 - lr: 0.0100
# Epoch 12/15
# 567/567 [==============================] - 2s 4ms/step - loss: 0.3265 - accuracy: 0.9001 - val_loss: 0.1802 - val_accuracy: 0.9449 - lr: 0.0100
# Epoch 13/15
# 567/567 [==============================] - 3s 6ms/step - loss: 0.3147 - accuracy: 0.9025 - val_loss: 0.1709 - val_accuracy: 0.9478 - lr: 0.0100
# Epoch 14/15
# 567/567 [==============================] - 3s 4ms/step - loss: 0.3079 - accuracy: 0.9047 - val_loss: 0.1627 - val_accuracy: 0.9484 - lr: 0.0100
# Epoch 15/15
# 567/567 [==============================] - 3s 4ms/step - loss: 0.2937 - accuracy: 0.9090 - val_loss: 0.1598 - val_accuracy: 0.9506 - lr: 0.0100

# %%
plt.plot(range(1,epochs+1),lenetHistory.history['val_loss'])
plt.plot(range(1,epochs+1),lenetNormHistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
# plt.legend(['LeNet 0 dropout', 'Lenet 1 dropout','Lenet 2 dropout'], loc='lower right')
plt.legend(['LeNet no normalization', 'Lenet normalized'], loc='lower right')
plt.show()

# %%
plt.plot(range(1,epochs+1),lenetHistory.history['val_accuracy'])
plt.plot(range(1,epochs+1),lenetNormHistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
# plt.legend(['LeNet 0 dropout', 'Lenet 1 dropout','Lenet 2 dropout'], loc='lower right')
plt.legend(['LeNet no normalization', 'Lenet normalized'], loc='lower right')
plt.show()

# %%
lenetReluHistory = trainModel(trainData,validationData,trainLabels,validationLabels, lenetActivation,'relu')
lenetSoftMaxHistory = trainModel(trainData,validationData,trainLabels,validationLabels, lenetActivation,'elu')
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_8 (Conv2D)           (None, 24, 24, 6)         156
#
#  max_pooling2d_8 (MaxPoolin  (None, 12, 12, 6)         0
#  g2D)
#
#  dropout_8 (Dropout)         (None, 12, 12, 6)         0
#
#  conv2d_9 (Conv2D)           (None, 8, 8, 16)          2416
#
#  max_pooling2d_9 (MaxPoolin  (None, 4, 4, 16)          0
#  g2D)
#
#  flatten_4 (Flatten)         (None, 256)               0
#
#  dense_12 (Dense)            (None, 120)               30840
#
#  dropout_9 (Dropout)         (None, 120)               0
#
#  dense_13 (Dense)            (None, 84)                10164
#
#  dense_14 (Dense)            (None, 10)                850
#
# =================================================================
# Total params: 44426 (173.54 KB)
# Trainable params: 44426 (173.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_8 (Conv2D)           (None, 24, 24, 6)         156
#
#  max_pooling2d_8 (MaxPoolin  (None, 12, 12, 6)         0
#  g2D)
#
#  dropout_8 (Dropout)         (None, 12, 12, 6)         0
#
#  conv2d_9 (Conv2D)           (None, 8, 8, 16)          2416
#
#  max_pooling2d_9 (MaxPoolin  (None, 4, 4, 16)          0
#  g2D)
#
#  flatten_4 (Flatten)         (None, 256)               0
#
#  dense_12 (Dense)            (None, 120)               30840
#
#  dropout_9 (Dropout)         (None, 120)               0
#
#  dense_13 (Dense)            (None, 84)                10164
#
#  dense_14 (Dense)            (None, 10)                850
#
# =================================================================
# Total params: 44426 (173.54 KB)
# Trainable params: 44426 (173.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/15
# 567/567 [==============================] - 5s 8ms/step - loss: 1.5495 - accuracy: 0.4683 - val_loss: 0.8337 - val_accuracy: 0.7579 - lr: 0.0100
# Epoch 2/15
# 567/567 [==============================] - 3s 5ms/step - loss: 0.9407 - accuracy: 0.6897 - val_loss: 0.5902 - val_accuracy: 0.8268 - lr: 0.0100
# Epoch 3/15
# 567/567 [==============================] - 2s 4ms/step - loss: 0.7686 - accuracy: 0.7511 - val_loss: 0.4820 - val_accuracy: 0.8590 - lr: 0.0100
# Epoch 4/15
# 567/567 [==============================] - 3s 5ms/step - loss: 0.6779 - accuracy: 0.7828 - val_loss: 0.4222 - val_accuracy: 0.8729 - lr: 0.0100
# Epoch 5/15
# 567/567 [==============================] - 2s 4ms/step - loss: 0.6134 - accuracy: 0.8043 - val_loss: 0.3682 - val_accuracy: 0.8906 - lr: 0.0100
# Epoch 6/15
# 567/567 [==============================] - 3s 5ms/step - loss: 0.5645 - accuracy: 0.8219 - val_loss: 0.3262 - val_accuracy: 0.9006 - lr: 0.0100
# Epoch 7/15
# 567/567 [==============================] - 3s 5ms/step - loss: 0.5261 - accuracy: 0.8337 - val_loss: 0.2922 - val_accuracy: 0.9124 - lr: 0.0100
# Epoch 8/15
# 567/567 [==============================] - 2s 4ms/step - loss: 0.4905 - accuracy: 0.8456 - val_loss: 0.2778 - val_accuracy: 0.9149 - lr: 0.0100
# Epoch 9/15
# 567/567 [==============================] - 2s 4ms/step - loss: 0.4610 - accuracy: 0.8543 - val_loss: 0.2529 - val_accuracy: 0.9222 - lr: 0.0100
# Epoch 10/15
# 567/567 [==============================] - 2s 4ms/step - loss: 0.4419 - accuracy: 0.8606 - val_loss: 0.2356 - val_accuracy: 0.9263 - lr: 0.0100
# Epoch 11/15
# 567/567 [==============================] - 3s 5ms/step - loss: 0.4166 - accuracy: 0.8685 - val_loss: 0.2237 - val_accuracy: 0.9337 - lr: 0.0100
# Epoch 12/15
# 567/567 [==============================] - 3s 6ms/step - loss: 0.4011 - accuracy: 0.8740 - val_loss: 0.2133 - val_accuracy: 0.9359 - lr: 0.0100
# Epoch 13/15
# 567/567 [==============================] - 2s 4ms/step - loss: 0.3856 - accuracy: 0.8800 - val_loss: 0.1990 - val_accuracy: 0.9417 - lr: 0.0100
# Epoch 14/15
# 567/567 [==============================] - 2s 4ms/step - loss: 0.3707 - accuracy: 0.8828 - val_loss: 0.1923 - val_accuracy: 0.9448 - lr: 0.0100
# Epoch 15/15
# 567/567 [==============================] - 2s 4ms/step - loss: 0.3574 - accuracy: 0.8886 - val_loss: 0.1853 - val_accuracy: 0.9459 - lr: 0.0100
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_10 (Conv2D)          (None, 24, 24, 6)         156
#
#  max_pooling2d_10 (MaxPooli  (None, 12, 12, 6)         0
#  ng2D)
#
#  dropout_10 (Dropout)        (None, 12, 12, 6)         0
#
#  conv2d_11 (Conv2D)          (None, 8, 8, 16)          2416
#
#  max_pooling2d_11 (MaxPooli  (None, 4, 4, 16)          0
#  ng2D)
#
#  flatten_5 (Flatten)         (None, 256)               0
#
#  dense_15 (Dense)            (None, 120)               30840
#
#  dropout_11 (Dropout)        (None, 120)               0
#
#  dense_16 (Dense)            (None, 84)                10164
#
#  dense_17 (Dense)            (None, 10)                850
#
# =================================================================
# Total params: 44426 (173.54 KB)
# Trainable params: 44426 (173.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_10 (Conv2D)          (None, 24, 24, 6)         156
#
#  max_pooling2d_10 (MaxPooli  (None, 12, 12, 6)         0
#  ng2D)
#
#  dropout_10 (Dropout)        (None, 12, 12, 6)         0
#
#  conv2d_11 (Conv2D)          (None, 8, 8, 16)          2416
#
#  max_pooling2d_11 (MaxPooli  (None, 4, 4, 16)          0
#  ng2D)
#
#  flatten_5 (Flatten)         (None, 256)               0
#
#  dense_15 (Dense)            (None, 120)               30840
#
#  dropout_11 (Dropout)        (None, 120)               0
#
#  dense_16 (Dense)            (None, 84)                10164
#
#  dense_17 (Dense)            (None, 10)                850
#
# =================================================================
# Total params: 44426 (173.54 KB)
# Trainable params: 44426 (173.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/15
# 567/567 [==============================] - 3s 5ms/step - loss: 1.2730 - accuracy: 0.5798 - val_loss: 0.6683 - val_accuracy: 0.7871 - lr: 0.0100
# Epoch 2/15
# 567/567 [==============================] - 3s 5ms/step - loss: 0.7697 - accuracy: 0.7528 - val_loss: 0.4791 - val_accuracy: 0.8478 - lr: 0.0100
# Epoch 3/15
# 567/567 [==============================] - 3s 5ms/step - loss: 0.6205 - accuracy: 0.8008 - val_loss: 0.3787 - val_accuracy: 0.8827 - lr: 0.0100
# Epoch 4/15
# 567/567 [==============================] - 3s 5ms/step - loss: 0.5341 - accuracy: 0.8284 - val_loss: 0.3247 - val_accuracy: 0.8994 - lr: 0.0100
# Epoch 5/15
# 567/567 [==============================] - 2s 4ms/step - loss: 0.4733 - accuracy: 0.8497 - val_loss: 0.2806 - val_accuracy: 0.9135 - lr: 0.0100
# Epoch 6/15
# 567/567 [==============================] - 3s 5ms/step - loss: 0.4295 - accuracy: 0.8641 - val_loss: 0.2546 - val_accuracy: 0.9259 - lr: 0.0100
# Epoch 7/15
# 567/567 [==============================] - 2s 4ms/step - loss: 0.3968 - accuracy: 0.8746 - val_loss: 0.2331 - val_accuracy: 0.9295 - lr: 0.0100
# Epoch 8/15
# 567/567 [==============================] - 2s 4ms/step - loss: 0.3717 - accuracy: 0.8828 - val_loss: 0.2112 - val_accuracy: 0.9356 - lr: 0.0100
# Epoch 9/15
# 567/567 [==============================] - 2s 4ms/step - loss: 0.3512 - accuracy: 0.8891 - val_loss: 0.1983 - val_accuracy: 0.9383 - lr: 0.0100
# Epoch 10/15
# 567/567 [==============================] - 2s 4ms/step - loss: 0.3315 - accuracy: 0.8959 - val_loss: 0.1885 - val_accuracy: 0.9421 - lr: 0.0100
# Epoch 11/15
# 567/567 [==============================] - 3s 6ms/step - loss: 0.3165 - accuracy: 0.9000 - val_loss: 0.1761 - val_accuracy: 0.9437 - lr: 0.0100
# Epoch 12/15
# 567/567 [==============================] - 3s 5ms/step - loss: 0.3029 - accuracy: 0.9041 - val_loss: 0.1673 - val_accuracy: 0.9473 - lr: 0.0100
# Epoch 13/15
# 567/567 [==============================] - 2s 4ms/step - loss: 0.2872 - accuracy: 0.9093 - val_loss: 0.1584 - val_accuracy: 0.9506 - lr: 0.0100
# Epoch 14/15
# 567/567 [==============================] - 2s 4ms/step - loss: 0.2784 - accuracy: 0.9141 - val_loss: 0.1515 - val_accuracy: 0.9508 - lr: 0.0100
# Epoch 15/15
# 567/567 [==============================] - 2s 4ms/step - loss: 0.2698 - accuracy: 0.9154 - val_loss: 0.1490 - val_accuracy: 0.9522 - lr: 0.0100

# %%
plt.plot(range(1,epochs+1),lenetReluHistory.history['val_loss'])
plt.plot(range(1,epochs+1),lenetSoftMaxHistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
# plt.legend(['LeNet 0 dropout', 'Lenet 1 dropout','Lenet 2 dropout'], loc='lower right')
plt.legend(['LeNet Relu', 'Lenet Elu'], loc='lower right')
plt.show()

# %%
plt.plot(range(1,epochs+1),lenetReluHistory.history['val_accuracy'])
plt.plot(range(1,epochs+1),lenetSoftMaxHistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
# plt.legend(['LeNet 0 dropout', 'Lenet 1 dropout','Lenet 2 dropout'], loc='lower right')
plt.legend(['LeNet ReLu', 'Lenet Elu'], loc='lower right')
plt.show()

# %%
lenetSgdHistory = trainModel(trainData,validationData,trainLabels,validationLabels, lenetOptimization,'sgd')
lenetAdamHistory = trainModel(trainData,validationData,trainLabels,validationLabels, lenetOptimization,'adam')
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 24, 24, 6)         156
#
#  max_pooling2d_12 (MaxPooli  (None, 12, 12, 6)         0
#  ng2D)
#
#  dropout_12 (Dropout)        (None, 12, 12, 6)         0
#
#  conv2d_13 (Conv2D)          (None, 8, 8, 16)          2416
#
#  max_pooling2d_13 (MaxPooli  (None, 4, 4, 16)          0
#  ng2D)
#
#  flatten_6 (Flatten)         (None, 256)               0
#
#  dense_18 (Dense)            (None, 120)               30840
#
#  dropout_13 (Dropout)        (None, 120)               0
#
#  dense_19 (Dense)            (None, 84)                10164
#
#  dense_20 (Dense)            (None, 10)                850
#
# =================================================================
# Total params: 44426 (173.54 KB)
# Trainable params: 44426 (173.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 24, 24, 6)         156
#
#  max_pooling2d_12 (MaxPooli  (None, 12, 12, 6)         0
#  ng2D)
#
#  dropout_12 (Dropout)        (None, 12, 12, 6)         0
#
#  conv2d_13 (Conv2D)          (None, 8, 8, 16)          2416
#
#  max_pooling2d_13 (MaxPooli  (None, 4, 4, 16)          0
#  ng2D)
#
#  flatten_6 (Flatten)         (None, 256)               0
#
#  dense_18 (Dense)            (None, 120)               30840
#
#  dropout_13 (Dropout)        (None, 120)               0
#
#  dense_19 (Dense)            (None, 84)                10164
#
#  dense_20 (Dense)            (None, 10)                850
#
# =================================================================
# Total params: 44426 (173.54 KB)
# Trainable params: 44426 (173.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/15
# 567/567 [==============================] - 4s 5ms/step - loss: 1.8156 - accuracy: 0.3702 - val_loss: 1.0923 - val_accuracy: 0.6832 - lr: 0.0100
# Epoch 2/15
# 567/567 [==============================] - 3s 4ms/step - loss: 1.1651 - accuracy: 0.6145 - val_loss: 0.7802 - val_accuracy: 0.7614 - lr: 0.0100
# Epoch 3/15
# 567/567 [==============================] - 3s 5ms/step - loss: 0.9691 - accuracy: 0.6821 - val_loss: 0.6729 - val_accuracy: 0.7898 - lr: 0.0100
# Epoch 4/15
# 567/567 [==============================] - 3s 5ms/step - loss: 0.8607 - accuracy: 0.7183 - val_loss: 0.5759 - val_accuracy: 0.8229 - lr: 0.0100
# Epoch 5/15
# 567/567 [==============================] - 3s 4ms/step - loss: 0.7724 - accuracy: 0.7484 - val_loss: 0.5174 - val_accuracy: 0.8441 - lr: 0.0100
# Epoch 6/15
# 567/567 [==============================] - 3s 4ms/step - loss: 0.7128 - accuracy: 0.7690 - val_loss: 0.4612 - val_accuracy: 0.8621 - lr: 0.0100
# Epoch 7/15
# 567/567 [==============================] - 3s 4ms/step - loss: 0.6645 - accuracy: 0.7858 - val_loss: 0.4218 - val_accuracy: 0.8714 - lr: 0.0100
# Epoch 8/15
# 567/567 [==============================] - 3s 6ms/step - loss: 0.6232 - accuracy: 0.7985 - val_loss: 0.3903 - val_accuracy: 0.8830 - lr: 0.0100
# Epoch 9/15
# 567/567 [==============================] - 3s 4ms/step - loss: 0.5920 - accuracy: 0.8094 - val_loss: 0.3677 - val_accuracy: 0.8956 - lr: 0.0100
# Epoch 10/15
# 567/567 [==============================] - 3s 4ms/step - loss: 0.5624 - accuracy: 0.8189 - val_loss: 0.3414 - val_accuracy: 0.8992 - lr: 0.0100
# Epoch 11/15
# 567/567 [==============================] - 3s 4ms/step - loss: 0.5377 - accuracy: 0.8284 - val_loss: 0.3180 - val_accuracy: 0.9063 - lr: 0.0100
# Epoch 12/15
# 567/567 [==============================] - 3s 5ms/step - loss: 0.5172 - accuracy: 0.8355 - val_loss: 0.2976 - val_accuracy: 0.9116 - lr: 0.0100
# Epoch 13/15
# 567/567 [==============================] - 3s 5ms/step - loss: 0.4977 - accuracy: 0.8426 - val_loss: 0.2858 - val_accuracy: 0.9116 - lr: 0.0100
# Epoch 14/15
# 567/567 [==============================] - 3s 5ms/step - loss: 0.4777 - accuracy: 0.8481 - val_loss: 0.2690 - val_accuracy: 0.9195 - lr: 0.0100
# Epoch 15/15
# 567/567 [==============================] - 3s 6ms/step - loss: 0.4632 - accuracy: 0.8543 - val_loss: 0.2668 - val_accuracy: 0.9202 - lr: 0.0100
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_14 (Conv2D)          (None, 24, 24, 6)         156
#
#  max_pooling2d_14 (MaxPooli  (None, 12, 12, 6)         0
#  ng2D)
#
#  dropout_14 (Dropout)        (None, 12, 12, 6)         0
#
#  conv2d_15 (Conv2D)          (None, 8, 8, 16)          2416
#
#  max_pooling2d_15 (MaxPooli  (None, 4, 4, 16)          0
#  ng2D)
#
#  flatten_7 (Flatten)         (None, 256)               0
#
#  dense_21 (Dense)            (None, 120)               30840
#
#  dropout_15 (Dropout)        (None, 120)               0
#
#  dense_22 (Dense)            (None, 84)                10164
#
#  dense_23 (Dense)            (None, 10)                850
#
# =================================================================
# Total params: 44426 (173.54 KB)
# Trainable params: 44426 (173.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_14 (Conv2D)          (None, 24, 24, 6)         156
#
#  max_pooling2d_14 (MaxPooli  (None, 12, 12, 6)         0
#  ng2D)
#
#  dropout_14 (Dropout)        (None, 12, 12, 6)         0
#
#  conv2d_15 (Conv2D)          (None, 8, 8, 16)          2416
#
#  max_pooling2d_15 (MaxPooli  (None, 4, 4, 16)          0
#  ng2D)
#
#  flatten_7 (Flatten)         (None, 256)               0
#
#  dense_21 (Dense)            (None, 120)               30840
#
#  dropout_15 (Dropout)        (None, 120)               0
#
#  dense_22 (Dense)            (None, 84)                10164
#
#  dense_23 (Dense)            (None, 10)                850
#
# =================================================================
# Total params: 44426 (173.54 KB)
# Trainable params: 44426 (173.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/15
# 567/567 [==============================] - 6s 6ms/step - loss: 0.9554 - accuracy: 0.6837 - val_loss: 0.3949 - val_accuracy: 0.8802 - lr: 0.0100
# Epoch 2/15
# 567/567 [==============================] - 3s 5ms/step - loss: 0.5352 - accuracy: 0.8365 - val_loss: 0.3118 - val_accuracy: 0.9083 - lr: 0.0100
# Epoch 3/15
# 567/567 [==============================] - 3s 5ms/step - loss: 0.4767 - accuracy: 0.8529 - val_loss: 0.2808 - val_accuracy: 0.9181 - lr: 0.0100
# Epoch 4/15
# 567/567 [==============================] - 3s 5ms/step - loss: 0.4478 - accuracy: 0.8654 - val_loss: 0.2720 - val_accuracy: 0.9294 - lr: 0.0100
# Epoch 5/15
# 567/567 [==============================] - 3s 6ms/step - loss: 0.4162 - accuracy: 0.8781 - val_loss: 0.2986 - val_accuracy: 0.9268 - lr: 0.0100
# Epoch 6/15
# 567/567 [==============================] - 3s 5ms/step - loss: 0.4066 - accuracy: 0.8791 - val_loss: 0.2466 - val_accuracy: 0.9310 - lr: 0.0100
# Epoch 7/15
# 567/567 [==============================] - 3s 5ms/step - loss: 0.3926 - accuracy: 0.8859 - val_loss: 0.2258 - val_accuracy: 0.9395 - lr: 0.0100
# Epoch 8/15
# 567/567 [==============================] - 3s 5ms/step - loss: 0.3864 - accuracy: 0.8892 - val_loss: 0.2243 - val_accuracy: 0.9360 - lr: 0.0100
# Epoch 9/15
# 567/567 [==============================] - 3s 6ms/step - loss: 0.3789 - accuracy: 0.8905 - val_loss: 0.2449 - val_accuracy: 0.9338 - lr: 0.0100
# Epoch 10/15
# 567/567 [==============================] - 3s 5ms/step - loss: 0.3755 - accuracy: 0.8931 - val_loss: 0.2411 - val_accuracy: 0.9390 - lr: 0.0100
# Epoch 11/15
# 567/567 [==============================] - 3s 4ms/step - loss: 0.3707 - accuracy: 0.8956 - val_loss: 0.2053 - val_accuracy: 0.9451 - lr: 0.0100
# Epoch 12/15
# 567/567 [==============================] - 3s 5ms/step - loss: 0.3701 - accuracy: 0.8946 - val_loss: 0.2070 - val_accuracy: 0.9470 - lr: 0.0100
# Epoch 13/15
# 567/567 [==============================] - 3s 5ms/step - loss: 0.3653 - accuracy: 0.8959 - val_loss: 0.1928 - val_accuracy: 0.9494 - lr: 0.0100
# Epoch 14/15
# 567/567 [==============================] - 4s 6ms/step - loss: 0.3600 - accuracy: 0.8973 - val_loss: 0.1975 - val_accuracy: 0.9444 - lr: 0.0100
# Epoch 15/15
# 567/567 [==============================] - 3s 5ms/step - loss: 0.3546 - accuracy: 0.9000 - val_loss: 0.1947 - val_accuracy: 0.9468 - lr: 0.0100

# %%
plt.plot(range(1,epochs+1),lenetSgdHistory.history['val_loss'])
plt.plot(range(1,epochs+1),lenetAdamHistory.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
# plt.legend(['LeNet 0 dropout', 'Lenet 1 dropout','Lenet 2 dropout'], loc='lower right')
plt.legend(['LeNet sgd', 'Lenet adam'], loc='lower right')
plt.show()

# %%
plt.plot(range(1,epochs+1),lenetSgdHistory.history['val_accuracy'])
plt.plot(range(1,epochs+1),lenetAdamHistory.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
# plt.legend(['LeNet 0 dropout', 'Lenet 1 dropout','Lenet 2 dropout'], loc='lower right')
plt.legend(['LeNet sgd', 'Lenet Adam'], loc='lower right')
plt.show()
